# %%
import pandas as pd

# Cargar usando la fila 3 como encabezado
df = pd.read_csv("../data/academic_performance_master.csv", header=3)

# Eliminar columnas completamente vacías
df = df.dropna(axis=1, how="all")

# Eliminar filas completamente vacías
df = df.dropna(how="all")

# Resetear índice
df = df.reset_index(drop=True)

print("Columnas del DataFrame limpio:")
print(df.columns.tolist())

print("\nPrimeras filas del DataFrame:")
print(df.head())
# Out:
# Columnas del DataFrame limpio:
# ['Periodo', 'Paralelo', 'Identificacion', 'Estudiante', 'Carrera', 'Nivel', 'Asignatura', 'Num_matricula', 'Unnamed: 9', 'Asistencia', 'Nota final', 'Estado', 'Unnamed: 13', 'Estado Matrícula', 'Tipo Ingreso', 'Cédula docente', 'Nombre docente']
#
# Primeras filas del DataFrame:
#    Periodo Paralelo Identificacion                    Estudiante  \
# 0  2020-2P        B     1104826365  ABRIGO ZAPATA KARINA CECILIA
# 1  2020-2P        L     1104826365  ABRIGO ZAPATA KARINA CECILIA
# 2  2020-2P        L     1104826365  ABRIGO ZAPATA KARINA CECILIA
# 3  2020-2P        L     1104826365  ABRIGO ZAPATA KARINA CECILIA
# 4  2020-2P        L     1104826365  ABRIGO ZAPATA KARINA CECILIA
#
#                                           Carrera    Nivel  \
# 0                           CDI-CENTRO DE IDIOMAS  PRIMERO
# 1  TAF-TECNOLOGIA SUPERIOR EN ASESORIA FINANCIERA  PRIMERO
# 2  TAF-TECNOLOGIA SUPERIOR EN ASESORIA FINANCIERA  PRIMERO
# ...

# %%
# Convertir asistencia y nota a valores numéricos
df["Asistencia"] = pd.to_numeric(df["Asistencia"], errors="coerce").fillna(0)
df["Nota final"] = pd.to_numeric(df["Nota final"], errors="coerce").fillna(0)

# Convertir numero de matrículas
df["Num_matricula"] = pd.to_numeric(df["Num_matricula"], errors="coerce").fillna(0)

# Crear variable objetivo
df["Aprobado"] = df["Estado"].apply(lambda x: 1 if str(x).strip().upper() == "APROBADO" else 0)

print("Columnas finales para el modelo:")
print(df.columns.tolist())

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Eliminar columnas basura
# ----> 2 df = df.drop(columns=["Unnamed: 9", "Unnamed: 13"])
#       4 # Convertir asistencia y nota a valores numéricos
#       5 df["Asistencia"] = pd.to_numeric(df["Asistencia"], errors="coerce")
#
# File c:\Users\mauca\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
# ...

# %% [markdown]
# MODELO SUPERVISADO

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Asegurar que las columnas numéricas estén limpias
df["Asistencia"] = pd.to_numeric(df["Asistencia"], errors="coerce").fillna(0)
df["Nota final"] = pd.to_numeric(df["Nota final"], errors="coerce").fillna(0)
df["Num_matricula"] = pd.to_numeric(df["Num_matricula"], errors="coerce").fillna(0)

# Seleccionar características
X = df[["Asistencia", "Nota final", "Num_matricula"]]
y = df["Aprobado"]

# Separar datos
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Escalamiento
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Modelo
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# Predicciones
y_pred = model.predict(X_test_scaled)

# Métricas
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nReporte de Clasificación:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48832\3569763791.py in ?()
#      18 )
#      19
#      20 # Escalar datos
#      21 scaler = StandardScaler()
# ---> 22 X_train_scaled = scaler.fit_transform(X_train)
#      23 X_test_scaled = scaler.transform(X_test)
#      24
#      25 # Modelo
#
# c:\Users\mauca\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# c:\Users\mauca\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     914                 )
#     915
# ...

# %% [markdown]
# Matriz de Confusión

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Reprobado", "Aprobado"],
            yticklabels=["Reprobado", "Aprobado"])
plt.title("Matriz de Confusión – Modelo Supervisado")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cm = confusion_matrix(y_test, y_pred)
#       3 plt.figure(figsize=(6,4))
#       4 sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
#       5             xticklabels=["Reprobado", "Aprobado"],
#       6             yticklabels=["Reprobado", "Aprobado"])
#
# NameError: name 'y_pred' is not defined
